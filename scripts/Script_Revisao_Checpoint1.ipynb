# %% [markdown]
# <pre>
# <img align="center" width="1000" src="https://raw.githubusercontent.com/andrelmfsantos/revisao_checkpoint1/main/images/header.png">
# </pre>

# %%
# Carregar bibliotecas
import numpy as np # biblioteca para manipular matrizes
import pandas as pd # biblioteca para manipular e tratar os dados

# %%
#import pandas as pd

# URL of the CSV file
#url = "https://raw.githubusercontent.com/andrelmfsantos/FIAP_2TDCPR_IA_MACHINE_LEARNING/main/datasets/Phishing_Legitimate_full.csv"
#url = "https://raw.githubusercontent.com/andrelmfsantos/FIAP_2TDCPR_IA_MACHINE_LEARNING/main/datasets/urls_phishing.csv"
url = "https://raw.githubusercontent.com/andrelmfsantos/revisao_checkpoint1/main/datasets/url_phishing.csv"
# Load the CSV file into a DataFrame
df = pd.read_csv(url)

# Display the first few rows of the DataFrame to verify
df.head(5)
# Out:
#                                                 urls  phishing  \
# 0  http://graphicriver.net/search?date=this-month...         0
# 1  http://ecnavi.jp/redirect/?url=http://www.cros...         0
# 2  https://hubpages.com/signin?explain=follow+Hub...         0
# 3  http://extratorrent.cc/torrent/4190536/AOMEI+B...         0
# 4  http://icicibank.com/Personal-Banking/offers/o...         0
#
#              Domain  IP Address in URL  @ Symbol in URL  Length of URL  \
# 0  graphicriver.net                  1                0            138
# 1         ecnavi.jp                  1                0            105
# 2      hubpages.com                  1                0             89
# 3   extratorrent.cc                  0                0            132
# 4     icicibank.com                  1                0            115
#
#    Depth of URL  Redirection "//" in URL  http/https in Domain name  \
# 0             1                        0                          0
# 1             2                        0                          0
# 2             1                        0                          0
# 3             3                        0                          0
# 4             3                        0                          0
#
#    Using URL Shortening Services  Prefix or Suffix "-" in Domain  DNS Record  \
# 0                              0                               0           1
# 1                              0                               0           1
# 2                              0                               0           1
# 3                              0                               0           0
# 4                              0                               0           1
#
#    Age of Domain End Period of Domain
# 0           18.0  2025-08-31 13:43:57
# 1           19.0  2025-01-31 00:00:00
# 2           19.0  2025-04-28 00:32:00
# 3           13.0  2024-12-03 12:08:35
# 4           28.0  2026-07-15 04:00:00

# %%
len(df)
# Out:
# 6500

# %%
ds = df.sample(n = 3000, random_state = 43)
len(ds)
# Out:
# 3000

# %%
# @title Subset

# CLASS_LABEL: Rótulo da classe, onde
#              0 indica uma URL legítima e
#              1 indica uma URL de phishing.

# Dividir o DataFrame em dois subconjuntos
df1 = ds[ds['phishing'] == 1] # phishing
df0 = ds[ds['phishing'] == 0] # legítima
df1.sample(5, random_state = 43)
# Out:
#                                                    urls  phishing  \
# 4608                https://transpoatdpnmdqenbzmnv.top/         1
# 6056              https://attyahooxxmail908.weebly.com/         1
# 5870   http://serviciosonlineficohsa.iceiy.com/home.php         1
# 707                              https://bit.ly/3LUSwvz         1
# 4086  https://docs.google.com/forms/d/e/1FAIpQLSdHKG...         1
#
#                                 Domain  IP Address in URL  @ Symbol in URL  \
# 4608        transpoatdpnmdqenbzmnv.top                  1                0
# 6056      attyahooxxmail908.weebly.com                  1                0
# 5870  serviciosonlineficohsa.iceiy.com                  1                0
# 707                             bit.ly                  1                0
# 4086                   docs.google.com                  1                0
#
#       Length of URL  Depth of URL  Redirection "//" in URL  \
# 4608             35             1                        0
# 6056             37             1                        0
# 5870             48             1                        0
# 707              22             1                        0
# 4086            110             5                        0
#
#       http/https in Domain name  Using URL Shortening Services  \
# 4608                          0                              0
# 6056                          0                              0
# 5870                          0                              0
# 707                           0                              1
# 4086                          0                              0
#
#       Prefix or Suffix "-" in Domain  DNS Record  Age of Domain  \
# 4608                               0           1            0.0
# 6056                               0           1           18.0
# 5870                               0           1            3.0
# 707                                0           1           16.0
# 4086                               0           1           26.0
#
#      End Period of Domain
# 4608  2025-08-07 11:03:36
# 6056  2025-03-28 23:25:07
# 5870  2024-12-06 10:50:01
# 707   2032-05-17 22:00:00
# 4086  2028-09-14 04:00:00

# %%
# @title Média
#5. UrlLength: Comprimento total da URL.

# Média de todas as observações da base
mean_value = df['Depth of URL'].mean()
print(f"A média da coluna 'UrlLength' é: {mean_value} (Todas URLs)")

# Média das URLs - Phishing
mean_value1 = df1['Depth of URL'].mean()
print(f"A média da coluna 'UrlLength' é: {mean_value1} (URLs Phishing)")

# Média das URLs - Legítima
mean_value0 = df0['Depth of URL'].mean()
print(f"A média da coluna 'UrlLength' é: {mean_value0} (URLs Legítima)")
# Out:
# A média da coluna 'UrlLength' é: 2.5606153846153847 (Todas URLs)
# A média da coluna 'UrlLength' é: 1.5185676392572944 (URLs Phishing)
# A média da coluna 'UrlLength' é: 3.601206434316354 (URLs Legítima)
